# %% [markdown]
# # Constituency Grammars with NLTK

# %% [markdown]
# ## Objectives
# - Understanding:
#     - relation between grammar and syntactic parse tree
#     - relation between grammar and syntactic categories
#     - relation between grammar and Part-of-Speech tags
#     - context free grammars (CFG)
#     - probabilistic context free grammars (PCFG)
# - Learning how to:
#     - define CFG in NLTK
#     - parse with CFG
#     - learn PCFGs from a treebank
#     - parse with PCFG
#     - generate sentences using a grammar in NLTK
#     - evaluate parser

# %% [markdown]
# ### Recommended Reading
# - Dan Jurafsky and James H. Martin. [__Speech and Language Processing__ (SLP)](https://web.stanford.edu/~jurafsky/slp3/) (3rd ed. draft)
# - Steven Bird, Ewan Klein, and Edward Loper. [__Natural Language Processing with Python__ (NLTK)](https://www.nltk.org/book/)

# %% [markdown]
# ### Covered Material
# - SLP
#     - [Chapter 12: Constituency Grammars](https://web.stanford.edu/~jurafsky/slp3/12.pdf)
#     - [Chapter 13: Constituency Parsing](https://web.stanford.edu/~jurafsky/slp3/13.pdf)
# - NLTK
#     - [Chapter 8: Analyzing Sentence Structure](https://www.nltk.org/book/ch08.html)

# %% [markdown]
# ### Requirements
#
# - [NLTK](https://www.nltk.org/)

# %% [markdown]
# ## 1. Grammars, Production Rules, and Parse Trees

# %% [markdown]
# In linguistics, [**syntax**](https://en.wikipedia.org/wiki/Syntax) is the study of how words and morphemes combine to form larger units such as phrases and sentences. Central concerns of syntax include word order, **grammatical relations**, **hierarchical sentence structure** (constituency), agreement, the nature of crosslinguistic variation, and the relationship between form and meaning.

# %% [markdown]
# In linguistics, the [**grammar**](https://en.wikipedia.org/wiki/Grammar) of a natural language is its set of structural constraints on speakers' or writers' composition of clauses, phrases, and words.

# %% [markdown]
# A [**context-free grammar (CFG)**](https://en.wikipedia.org/wiki/Context-free_grammar) is a formal grammar whose [**production rules**](https://en.wikipedia.org/wiki/Production_(computer_science)) are of the form:
#
# $$A \to \alpha$$
#
# where:
# - $A$ a single nonterminal symbol
# - $\alpha$  a string of terminals and/or nonterminals

# %% [markdown]
# [**Parsing**](https://en.wikipedia.org/wiki/Parsing), syntax analysis, or syntactic analysis is the process of analyzing a string of symbols, either in natural language, computer languages or data structures, conforming to the rules of a formal grammar.
# Within computational linguistics the term is used to refer to the formal analysis by a computer of a sentence or other string of words into its **constituents**, resulting in a **parse tree** showing their syntactic relation to each other.

# %% [markdown]
# A [**parse tree**](https://en.wikipedia.org/wiki/Parse_tree) or **parsing tree** or **derivation tree** or **concrete syntax tree** is an ordered, rooted tree that represents the syntactic structure of a string according to some **context-free grammar**. The term parse tree itself is used primarily in computational linguistics; in theoretical syntax, the term syntax tree is more common.

# %% [markdown]
# ### 1.1. Parse Tree Representation
# One of the possible parse trees for a sentence `I saw the man with a telescope` is as below:

# %% [markdown]
# ```
#       S
#   ____|___________
#  |                VP
#  |     ___________|________
#  |    |       |            PP
#  |    |       |        ____|___
#  NP   |       NP      |        NP
#  |    |    ___|___    |     ___|______
# PRON  V  Det      N   P   Det         N
#  |    |   |       |   |    |          |
#  I   saw the     man with  a      telescope
#  ```

# %% [markdown]
# To occupy less space, a parse tree is usually represented using "bracketed expressions", where brackets enclose each **constituent** and the first element of the expression is the tree-node label.
#
# ```
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# ```

# %% [markdown]
# It is common to write a parse tree in a less readable one-line expression:
#
# ```
# (S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man)) (PP (P with) (NP (Det a) (N telescope)))))
# ```

# %% [markdown]
# ### 1.2. Parse Trees in NLTK

# %% [markdown]
# NLTK provides `Tree` class for representing hierarchical language structures. The class implements many useful methods. <br> Full documentation [HERE](https://www.nltk.org/api/nltk.tree.tree.html)

# %% [markdown]
# #### 1.2.1. "Core" Methods
#
# - `fromstring()` reads a bracketed tree string and return the resulting tree
#
# - `productions()` generate the productions that correspond to the non-terminal nodes of the tree.
#     - For each subtree of the form `(P: C1 C2 ... Cn)` this produces a production of the form `P -> C1 C2 ... Cn`.
#
# - `label()` returns the node label of the tree
#
# - `subtrees()` generates all the subtrees of this tree
#
# - `pos()` return a sequence of pos-tagged words extracted from the tree.
#
# - `leaves()` returns the leaves of the tree.
#
# - `flatten()` return a flat version of the tree, with all non-root non-terminals removed.

# %%
from nltk.tree import Tree
sent = "I saw the man with a telescope"
parse_tree_str = "(S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man)) (PP (P with) (NP (Det a) (N telescope)))))"

tree = Tree.fromstring(parse_tree_str)

# %%
# prints bracketed expression for the parse tree
print(tree)
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))

# %%
# prints all the subtrees
for stree in tree.subtrees():
    print('-'*89)
    print(stree)
# Out:
# -----------------------------------------------------------------------------------------
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# -----------------------------------------------------------------------------------------
# (NP (PRON I))
# -----------------------------------------------------------------------------------------
# (PRON I)
# -----------------------------------------------------------------------------------------
# (VP
#   (V saw)
#   (NP (Det the) (N man))
#   (PP (P with) (NP (Det a) (N telescope))))
# -----------------------------------------------------------------------------------------
# (V saw)
# -----------------------------------------------------------------------------------------
# (NP (Det the) (N man))
# -----------------------------------------------------------------------------------------
# (Det the)
# -----------------------------------------------------------------------------------------
# (N man)
# -----------------------------------------------------------------------------------------
# (PP (P with) (NP (Det a) (N telescope)))
# -----------------------------------------------------------------------------------------
# (P with)
# -----------------------------------------------------------------------------------------
# (NP (Det a) (N telescope))
# -----------------------------------------------------------------------------------------
# (Det a)
# -----------------------------------------------------------------------------------------
# (N telescope)

# %% [markdown]
# #### 1.2.2 Visualizaing Parse Trees
#
# In the code above, we have printed the parse tree using `print()` method, which prints a _bracketed expression_ tree.
# It is also possible to visualize syntactic trees of using other method:
#
# - `pprint()` the same as above
# - `pretty_print()` draws ASCII tree (the original example)
# - `draw()` opens a new window containing a graphical diagram of this tree.
# - `tree` a call to a tree draws it using `svgling`
#     - requires `svgling` module to be installed (`pip install svgling`)
#     - GitHub https://github.com/rawlins/svgling

# %%
tree
print(tree.pretty_print(unicodelines=True, nodedist=4))
# Out:
#          S
#  ┌───────┴────────────────────┐
#  │                            VP
#  │       ┌─────────────┬──────┴──────────────┐
#  │       │             │                     PP
#  │       │             │             ┌───────┴──────┐
#  NP      │             NP            │              NP
#  │       │      ┌──────┴──────┐      │       ┌──────┴─────────┐
# PRON     V     Det            N      P      Det               N
#  │       │      │             │      │       │                │
#  I      saw    the           man    with     a            telescope
#
# None

# %%
from pprint import pprint
print(tree.pprint())
print(tree.pretty_print()) # or
print(tree.pretty_print(unicodelines=True, nodedist=4))
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# None
#       S
#   ____|___________
#  |                VP
#  |     ___________|________
#  |    |       |            PP
#  |    |       |        ____|___
#  NP   |       NP      |        NP
#  |    |    ___|___    |     ___|______
# PRON  V  Det      N   P   Det         N
#  |    |   |       |   |    |          |
#  I   saw the     man with  a      telescope
#
# None
#          S
#  ┌───────┴────────────────────┐
#  │                            VP
#  │       ┌─────────────┬──────┴──────────────┐
#  │       │             │                     PP
#  │       │             │             ┌───────┴──────┐
#  NP      │             NP            │              NP
#  │       │      ┌──────┴──────┐      │       ┌──────┴─────────┐
# PRON     V     Det            N      P      Det               N
#  │       │      │             │      │       │                │
#  I      saw    the           man    with     a            telescope
#
# None

# %%
tree.draw()

# %% [markdown]
# #### Exercise
# Familiarize with the [`Tree`](https://www.nltk.org/api/nltk.tree.tree.html) class.
#
# - Consult the documentation for more detail (and other methods)
# - Try each of the "core" methods listed above
#     - see production rules, leaves, and pos
#
# ######   "Core" Methods
#
# - `fromstring()` reads a bracketed tree string and return the resulting tree
#
# - `productions()` generate the productions that correspond to the non-terminal nodes of the tree.
#     - For each subtree of the form `(P: C1 C2 ... Cn)` this produces a production of the form `P -> C1 C2 ... Cn`.
#
# - `label()` returns the node label of the tree
#
# - `subtrees()` generates all the subtrees of this tree
#
# - `pos()` return a sequence of pos-tagged words extracted from the tree.
#
# - `leaves()` returns the leaves of the tree.
#
# - `flatten()` return a flat version of the tree, with all non-root non-terminals removed.

# %%
# Productions
print('Productions:', tree.productions())

# Label
print('Label:', tree.label())

# Pos tags
print('Pos Tags:', tree.pos())

# Leaves 
print('Leaves:', tree.leaves())

# Flatten
print('Flatten:', tree.flatten())
# Out:
# Productions: [S -> NP VP, NP -> PRON, PRON -> 'I', VP -> V NP PP, V -> 'saw', NP -> Det N, Det -> 'the', N -> 'man', PP -> P NP, P -> 'with', NP -> Det N, Det -> 'a', N -> 'telescope']
# Label: S
# Pos Tags: [('I', 'PRON'), ('saw', 'V'), ('the', 'Det'), ('man', 'N'), ('with', 'P'), ('a', 'Det'), ('telescope', 'N')]
# Leaves: ['I', 'saw', 'the', 'man', 'with', 'a', 'telescope']
# Flatten: (S I saw the man with a telescope)

# %% [markdown]
# ## 2. Context Free Grammars (CFG)

# %% [markdown]
# ### 2.1. Defining Context Free Grammars
#
# CFG are defined by a *start symbol* and a set of *production rules*. The *start symbol* defines the root node of parse trees (usually __S__).
#
# *Production rules* specify allowed parent-child relations in a parse tree. Each production specifies what node can be the parent of a particular set of children nodes.
#
# For example, the production `S -> NP VP` specifies that an `S` node can be the parent of an `NP` node and a `VP` node.
#
# The left-hand side of a production rules specifies potential *non-terminal* parent nodes; while right-hand side specifies list of allowed *non-terminal* and *terminal* (text) children.
#
# A production like `VP -> V NP | VP PP` has a disjunction on the right-hand side, shown by the `|` and is an abbreviation for the two productions `VP -> V NP` and `VP -> V NP PP`.

# %% [markdown]
# #### 2.1.1 Syntactic Categories
#
# | __Symbol__ | __Meaning__ | __Example__ |
# |:-----------|:------------|:------------|
# | S   | sentence             | I saw the man |
# | NP  | noun phrase          | the man |
# | VP  | verb phrase          | saw the man |
# | PP  | prepositional phrase | with a telescope |
# | Det | determiner  | the |
# | N   | noun        | man |
# | V   | verb        | saw |
# | P   | preposition | with |
#
#
# - Non-Terminals: `S`, `NP`, `VP`, `PP`
# - Pre-Terminals: `Det`, `N`, `V`, `P` (Part-of-Speech Tags)
# - Terminals (Leaves): the, man, saw, ...

# %% [markdown]
# ### 2.2. Defining Context Free Grammars in NLTK
#
# The grammar can be defined as a string or as a list of strings of production rules.

# %%
import nltk

rules = [
    'S -> NP VP',
    'NP -> Det N | Det N PP | PRON',
    'VP -> V NP | V NP PP',
    'PP -> P NP',
    'Det -> "the" | "a"',
    'N -> "man" | "telescope"',
    'PRON -> "I"',
    'V -> "saw"',
    'P -> "with"'   
]

# 
toy_grammar = nltk.CFG.fromstring(rules)

print(toy_grammar)
# Out:
# Grammar with 14 productions (start state = S)
#     S -> NP VP
#     NP -> Det N
#     NP -> Det N PP
#     NP -> PRON
#     VP -> V NP
#     VP -> V NP PP
#     PP -> P NP
#     Det -> 'the'
#     Det -> 'a'
#     N -> 'man'
#     N -> 'telescope'
#     PRON -> 'I'
#     V -> 'saw'
#     P -> 'with'

# %% [markdown]
# Grammar object has 2 components:
# - start symbol
# - production rules
#
# Those can be access as follows.

# %%
print(toy_grammar.start())
# Out:
# S

# %%
print(toy_grammar.productions())
# Out:
# [S -> NP VP, NP -> Det N, NP -> Det N PP, NP -> PRON, VP -> V NP, VP -> V NP PP, PP -> P NP, Det -> 'the', Det -> 'a', N -> 'man', N -> 'telescope', PRON -> 'I', V -> 'saw', P -> 'with']

# %% [markdown]
# Each production has 2 parts:
# - left-hand side
# - right-hand side
#
# which can be accessed as follows:

# %%
rule = toy_grammar.productions()[0]
print(rule.lhs())
print(rule.rhs())
# Out:
# S
# (NP, VP)

# %% [markdown]
# __Grammar__'s `productions(lhs=None, rhs=None, empty=False)` methos returns the grammar productions, filtered by the left-hand side or the first item in the right-hand side.
#
# __Parameters__
# - `lhs` -- Only return productions with the given left-hand side.
# - `rhs` -- Only return productions with the given first item in the right-hand side.
# - `empty` -- Only return productions with an empty right-hand side

# %%
from nltk import Nonterminal
toy_grammar.productions(lhs=Nonterminal('NP'))
# Out:
# [NP -> Det N, NP -> Det N PP, NP -> PRON]

# %%
toy_grammar.productions(rhs=Nonterminal('NP'))
# Out:
# [S -> NP VP]

# %%
toy_grammar.productions(empty=True)
# Out:
# dict_values([])

# %% [markdown]
# ### 2.3. Parsing with CFG
#
# > A parser processes input sentences according to the productions of a grammar, and builds one or more constituent structures that conform to the grammar. A grammar is a declarative specification of well-formedness — it is actually just a string, not a program. A parser is a procedural interpretation of the grammar. It searches through the space of trees licensed by a grammar to find one that has the required sentence along its fringe (outer edges).

# %% [markdown]
# #### 2.3.1. Available CFG Parsers in NLTK
#
# - Recursive descent parsing
#     - top-down algorithm
#     - pro: finds all successful parses.
#     - con: inefficient. will try all rules brute-force, even the ones that do not match the input. Goes into an infinite loop when handling a left-recursive rule.
#     - `nltk.RecursiveDescentParser()`
#
# - Shift-reduce parsing
#     - bottom-up algorithm
#     - pro: efficient. only works with the rules that match input words.
#     - con: may fail to find a legitimate parse even when there is one.
#     - `nltk.ShiftReduceParser()`
#
# - The left-corner parser
#     - a top-down parser with bottom-up filtering
#     - `nltk.LeftCornerChartParser()`: combines left-corner parsing and chart parsing
#
# - Chart parsing
#     - utilizes dynamic programming: builds and refers to well-formed substring tables (WFST)
#     - pro: efficient.
#     - con: may take up a big memory space when dealing with a long sentence.
#     - `nltk.ChartParser()`

# %%
rules = [
    'S -> NP VP',
    'NP -> Det N | Det N PP | PRON',
    'VP -> V NP | V NP PP',
    'PP -> P NP',
    'Det -> "the" | "a"',
    'N -> "man" | "telescope"',
    'PRON -> "I"',
    'V -> "saw"',
    'P -> "with"'   
]

toy_grammar = nltk.CFG.fromstring(rules)

# %%
parser = nltk.ChartParser(toy_grammar)

sent = "I saw the man with a telescope"

for tree in parser.parse(sent.split()):
    print(tree)
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))

# %% [markdown]
# The sentence produces two possible parse trees. Thus, it is said to be structurally ambiguous -- prepositional phrase attachment ambiguity.

# %% [markdown]
# #### Exercise
#
# - Define grammar that covers the following sentences.
#
#     - show flights from new york to los angeles
#     - list flights from new york to los angeles
#     - show flights from new york
#     - list flights to los angeles
#     - list flights
# - Use one of the parsers to parse the sentences (i.e. test your grammar)
#
# **Note:** <br>
# - start from Verb Pharse
# - Prepositional Phrase (PP) are composed of a preposition and a Noun Phrase
# - 'los' and 'angeles' are two consecutive nouns (N) (same for new york)
#
# #### Useful reminder from above
#
#
# | __Symbol__ | __Meaning__ | __Example__ |
# |:-----------|:------------|:------------|
# | S   | sentence             | I saw the man |
# | NP  | noun phrase          | the man |
# | VP  | verb phrase          | saw the man |
# | PP  | prepositional phrase | with a telescope |
# | Det | determiner  | the |
# | N   | noun        | man |
# | V   | verb        | saw |
# | P   | preposition | with |
#
#
# - Non-Terminals: `S`, `NP`, `VP`, `PP`
# - Pre-Terminals: `Det`, `N`, `V`, `P` (Part-of-Speech Tags)
# - Terminals (Leaves): the, man, saw, ...

# %%
# test setenteces
test_sents = [
    "show flights from new york to los angeles", 
    "list flights from new york to los angeles",
    "show flights from new york",
    "list flights to los angeles",
    "list flights"
]

# %%
rules = [
    'S -> VP',
    'VP -> V NP | V NP PP | V NP PP PP',
    'NP -> N | N N',
    'PP -> P NP | PP',
    'P -> "from" | "to"',
    'N -> "flights" | "new" | "york" | "los" | "angeles"',
    'V -> "show" | "list"',
]

toy_grammar = nltk.CFG.fromstring(rules)

# %%
parser = nltk.ChartParser(toy_grammar)

for sent in test_sents:
    for tree in parser.parse(sent.split()):
        print(tree)
        print(tree.pretty_print())
# Out:
# (S
#   (VP
#     (V show)
#     (NP (N flights))
#     (PP (P from) (NP (N new) (N york)))
#     (PP (P to) (NP (N los) (N angeles)))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# show flights from new     york  to los     angeles
#
# None
# (S
#   (VP
#     (V show)
#     (NP (N flights))
#     (PP (PP (P from) (NP (N new) (N york))))
#     (PP (P to) (NP (N los) (N angeles)))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          PP               |
#  |      |          |                |
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# show flights from new     york  to los     angeles
#
# None
# (S
#   (VP
#     (V show)
#     (NP (N flights))
#     (PP (P from) (NP (N new) (N york)))
#     (PP (PP (P to) (NP (N los) (N angeles))))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          |                PP
#  |      |          |                |
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# show flights from new     york  to los     angeles
#
# None
# (S
#   (VP
#     (V show)
#     (NP (N flights))
#     (PP (PP (P from) (NP (N new) (N york))))
#     (PP (PP (P to) (NP (N los) (N angeles))))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          PP               PP
#  |      |          |                |
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# show flights from new     york  to los     angeles
#
# None
# (S
#   (VP
#     (V list)
#     (NP (N flights))
#     (PP (P from) (NP (N new) (N york)))
#     (PP (P to) (NP (N los) (N angeles)))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# list flights from new     york  to los     angeles
#
# None
# (S
#   (VP
#     (V list)
#     (NP (N flights))
#     (PP (PP (P from) (NP (N new) (N york))))
#     (PP (P to) (NP (N los) (N angeles)))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          PP               |
#  |      |          |                |
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# list flights from new     york  to los     angeles
#
# None
# (S
#   (VP
#     (V list)
#     (NP (N flights))
#     (PP (P from) (NP (N new) (N york)))
#     (PP (PP (P to) (NP (N los) (N angeles))))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          |                PP
#  |      |          |                |
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# list flights from new     york  to los     angeles
#
# None
# (S
#   (VP
#     (V list)
#     (NP (N flights))
#     (PP (PP (P from) (NP (N new) (N york))))
#     (PP (PP (P to) (NP (N los) (N angeles))))))
#                    S
#                    |
#                    VP
#   _________________|________________
#  |      |          PP               PP
#  |      |          |                |
#  |      |          PP               PP
#  |      |      ____|___          ___|___
#  |      NP    |        NP       |       NP
#  |      |     |     ___|___     |    ___|_____
#  V      N     P    N       N    P   N         N
#  |      |     |    |       |    |   |         |
# list flights from new     york  to los     angeles
#
# None
# (S
#   (VP (V show) (NP (N flights)) (PP (P from) (NP (N new) (N york)))))
#               S
#               |
#               VP
#   ____________|____
#  |      |          PP
#  |      |      ____|___
#  |      NP    |        NP
#  |      |     |     ___|___
#  V      N     P    N       N
#  |      |     |    |       |
# show flights from new     york
#
# None
# (S
#   (VP
#     (V show)
#     (NP (N flights))
#     (PP (PP (P from) (NP (N new) (N york))))))
#               S
#               |
#               VP
#   ____________|____
#  |      |          PP
#  |      |          |
#  |      |          PP
#  |      |      ____|___
#  |      NP    |        NP
#  |      |     |     ___|___
#  V      N     P    N       N
#  |      |     |    |       |
# show flights from new     york
#
# None
# (S
#   (VP (V list) (NP (N flights)) (PP (P to) (NP (N los) (N angeles)))))
#               S
#               |
#               VP
#   ____________|___
#  |      |         PP
#  |      |      ___|___
#  |      NP    |       NP
#  |      |     |    ___|_____
#  V      N     P   N         N
#  |      |     |   |         |
# list flights  to los     angeles
#
# None
# (S
#   (VP
#     (V list)
#     (NP (N flights))
#     (PP (PP (P to) (NP (N los) (N angeles))))))
#               S
#               |
#               VP
#   ____________|___
#  |      |         PP
#  |      |         |
#  |      |         PP
#  |      |      ___|___
#  |      NP    |       NP
#  |      |     |    ___|_____
#  V      N     P   N         N
#  |      |     |   |         |
# list flights  to los     angeles
#
# None
# (S (VP (V list) (NP (N flights))))
#       S
#       |
#       VP
#   ____|_____
#  |          NP
#  |          |
#  V          N
#  |          |
# list     flights
#
# None

# %% [markdown]
# ### 2.3.2. "Real" Grammars

# %% [markdown]
# It is possible to load a grammar written by someone else into NLTK.
#
# - run `nltk.download()`
# - go to `Models` tab
# - download `large_grammars`

# %%
nltk.download('large_grammars')
# Out:
# [nltk_data] Downloading package large_grammars to /home/dhilab-
# [nltk_data]     mattia/nltk_data...
# [nltk_data]   Unzipping grammars/large_grammars.zip.
# True

# %%
atis_grammar = nltk.data.load('grammars/large_grammars/atis.cfg')
atis_parser = nltk.ChartParser(atis_grammar)

# %%
atis_grammar
# Out:
# <Grammar with 5517 productions>

# %% [markdown]
# The grammar comes with some test sentences.

# %%
atis_test_sentences = nltk.data.load('grammars/large_grammars/atis_sentences.txt')
atis_test_sentences = nltk.parse.util.extract_test_sentences(atis_test_sentences)
print(atis_test_sentences[0])
# Out:
# (['i', 'need', 'a', 'flight', 'from', 'charlotte', 'to', 'las', 'vegas', 'that', 'makes', 'a', 'stop', 'in', 'saint', 'louis', '.'], 2085)

# %% [markdown]
# Each test sentence is a tuple of a list of sentence words and a number of possible parses with respect to the grammar.

# %%
# let's check the number of parses our parser produces
for sent, pnum in atis_test_sentences[:3]:
    parses = atis_parser.parse(sent)
    print(len(list(parses)), pnum)
# Out:
# 2085 2085
# 1380 1380
# 50 50

# %% [markdown]
# #### Exercise
# Parse the sentences from the excercise above using **ATIS_GRAMMAR**
# - try different parsers
# - output the number of parses each sentence yields

# %%
atis_parser = nltk.ChartParser(atis_grammar, trace=2)
for sent in test_sents:
    parses = atis_parser.parse(sent.split())
    print(len(list(parses)))
# Out:
# |.show.flig.from.new .york. to .los .ange.|
# Leaf Init Rule:
# |[----]    .    .    .    .    .    .    .| [0:1] 'show'
# |.    [----]    .    .    .    .    .    .| [1:2] 'flights'
# |.    .    [----]    .    .    .    .    .| [2:3] 'from'
# |.    .    .    [----]    .    .    .    .| [3:4] 'new'
# |.    .    .    .    [----]    .    .    .| [4:5] 'york'
# |.    .    .    .    .    [----]    .    .| [5:6] 'to'
# |.    .    .    .    .    .    [----]    .| [6:7] 'los'
# |.    .    .    .    .    .    .    [----]| [7:8] 'angeles'
# Bottom Up Predict Combine Rule:
# |[----]    .    .    .    .    .    .    .| [0:1] show -> 'show' *
# Bottom Up Predict Combine Rule:
# |[----]    .    .    .    .    .    .    .| [0:1] NOUN_NN -> show *
# |[---->    .    .    .    .    .    .    .| [0:1] NOUN_NN -> show * business
# |[---->    .    .    .    .    .    .    .| [0:1] NOUN_NNS -> show * time
# |[----]    .    .    .    .    .    .    .| [0:1] VERB_VB -> show *
# Bottom Up Predict Combine Rule:
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> VERB_VB * NP_PPSS AVP_QL pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> VERB_VB * NP_PPSS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NPS AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AJP_JJ PP_NPS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_DTS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NNS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NP AVPNP_CD AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AVPNP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AVPNP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * INFCL_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_NP NP_NN AVPNP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NREL_BER pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_NP NP_NN AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NP PP_NPS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP PP_CC NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_CC PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP PP_CC AVPNP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_DTS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NP PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_ONS AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AVP_RB AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_NN AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_CC PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AVPNP_NN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NREL_BER pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AVPNP_NN PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NP PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN AJP_JJ AVPNP_NN PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPS PP_PPO pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * AJP_JJR pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * AJP_JJT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NN NP_NN PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NNS AVP_RB PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO AVP_RB PP_NNS COMPCL_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS AVPNP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_ONS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS AVPNP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NPS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NN AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_NP IJ_UH NP_DT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NNS PP_NP PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_CD AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN IJ_UH AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP NP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NPS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NN NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN NREL_BEZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_ONS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_NNS AVPNP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NP AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AJP_JJ PP_NP PP_VBG pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO COMPCL_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN AJP_JJ AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NP PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AJP_JJ PP_NP PP_NN PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_JJT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AJP_JJ AVPNP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NNS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_CC PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_CD PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_NP IJ_UH AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_PPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_NN NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS AJP_JJ AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN SUBCL_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_DT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NN AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN AJP_JJ PP_NP PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NPS AVPNP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NNS PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NN PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO PP_PPO AVP_RB AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NP PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_PPO NREL_BER pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NPS PP_NP PP_NN PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN AVPNP_CD AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO COMPCL_VBZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NP PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS NP_NN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NPS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_CC PP_NP PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NP PP_NP PP_NN AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_CC PP_NP PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN AVP_RB PP_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_DTS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_CC PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS NP_NN PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_NP PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_CC PP_NP PP_NP PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NN PP_NP PP_NP PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO RELCL_VBZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NREL_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP AJP_JJ PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS IJ_UH pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS RELCL_BEZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_CC PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PRPRTCL_VBG pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NNS AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_NN IJ_UH pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_VB -> VERB_VB * NP_PPO NP_NNS PP_NP PP_NP pt_char_per
# |[----]    .    .    .    .    .    .    .| [0:1] INFCL_VB -> VERB_VB *
# |[---->    .    .    .    .    .    .    .| [0:1] INFCL_VB -> VERB_VB * NP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] INFCL_VB -> VERB_VB * NP_PPO PP_NN PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] INFCL_VB -> VERB_VB * NREL_BEZ
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP AVP_RB PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_NP PP_CD
# |[----]    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB *
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_CD AVPNP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_DTS
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_NPS PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_CD NP_PPS
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * AVP_RB PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_PPO NP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * AVP_RB PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * AJP_JJR
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_DTS
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP AVPNP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NPS PP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NP PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NPS PP_NP PP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP SUBCL_BE
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NP PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * AVP_QL
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * AVPNP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP PP_NP AVP_RB
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * AVP_RB
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NP AVPNP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_CD NP_PPO NP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * SUBCL_BE
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NNS PP_NP PP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_PPO NP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PREP_IN PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * PP_NP AVPNP_CD AVPNP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_PPS PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_NN PP_DT
# |[---->    .    .    .    .    .    .    .| [0:1] VP_VB -> VERB_VB * NP_DT
# Bottom Up Predict Combine Rule:
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_DOZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_MD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_VBN CONJ_CC VP_BEZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_VBG pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_BE pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_HVZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_BEZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> VP_VB * CONJ_CC VP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] IMPR_CC -> VP_VB * CONJ_CC VP_VB pt_char_per
# Bottom Up Predict Combine Rule:
# |[----]    .    .    .    .    .    .    .| [0:1] AVPNP_NN -> NOUN_NN *
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_NP AVP_RB
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * NAPPOS_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * NAPPOS_NP AVPNP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * AVPNP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * RELCL_VBZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PRPRTCL_VBG pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_VBG
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * AJP_JJ PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * QUANP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * COMPCL_VBZ
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NNS PP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_NP PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * AVPNP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * QUANP_ABN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_NPS PP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * RELCL_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * NAPPOS_NP PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * NAPPOS_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * NAPPOS_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * _s
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * NAPPOS_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PREP_IN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * RELCL_CC
# |[----]    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN *
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * AVPNP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * ADJ_ABL pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * AJP_JJ
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_DT
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * NAPPOS_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * LABEL_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * RELCL_VB
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NNS PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PTPRTCL_VBN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NOUN_NN * PP_NNS
# Bottom Up Predict Combine Rule:
# |[---->    .    .    .    .    .    .    .| [0:1] AVPNP_CC -> NP_NN * CONJ_CC
# |[---->    .    .    .    .    .    .    .| [0:1] AVPNP_CC -> NP_NN * CONJ_CC NP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] AVPNP_CC -> NP_NN * CONJ_CC AVP_RB NP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] AVPNP_CC -> NP_NN * CONJ_CC NP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] AVPNP_NN -> NP_NN * NOUN_NN
# |[---->    .    .    .    .    .    .    .| [0:1] AVPNP_NN -> NP_NN * NOUN_NN RELCL_VB
# |[---->    .    .    .    .    .    .    .| [0:1] COMPCL_BEZ -> NP_NN * VERB_BEZ NP_PPS
# |[---->    .    .    .    .    .    .    .| [0:1] COMPCL_BEZ -> NP_NN * VERB_BEZ NP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] COMPCL_DOZ -> NP_NN * VERB_DOZ NP_WPS
# |[---->    .    .    .    .    .    .    .| [0:1] COMPCL_VB -> NP_NN * VERB_VB NP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] COMPCL_VBZ -> NP_NN * VERB_VBZ AVP_RB
# |[---->    .    .    .    .    .    .    .| [0:1] COMPCL_VBZ -> NP_NN * VERB_VBZ NP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] COMPCL_VBZ -> NP_NN * VERB_VBZ AVP_RB NP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BE -> NP_NN * VERB_MD pt_verb_be PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BE -> NP_NN * VERB_MD pt_verb_be NP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BE -> NP_NN * VERB_MD pt_verb_be PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BE -> NP_NN * VERB_MD pt_verb_be NP_NP AVPNP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BER -> NP_NN * pt_verb_ber PP_NNS NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BER -> NP_NN * pt_verb_ber NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BER -> NP_NN * pt_verb_ber AVP_RB NP_CC PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BER -> NP_NN * pt_verb_ber NP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BER -> NP_NN * pt_verb_ber NP_DTS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BER -> NP_NN * pt_verb_ber PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BER -> NP_NN * NP_DTS pt_verb_ber AVP_RB NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ AJP_JJT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_NN AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_WPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ AJP_JJ PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ AVP_RB NP_NN PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_NN AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ PP_NP PP_NPS AVPNP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_PPS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ NP_DT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ PP_NP PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ PP_NP PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ PP_NP PP_NP AVPNP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_BEZ -> NP_NN * VERB_BEZ AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> NP_NN * VP_VBZ CONJ_CC VP_VBZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> NP_NN * VP_VBZ CONJ_CC VP_HVZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> NP_NN * VERB_MD VP_VB CONJ_CC VP_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_CC -> NP_NN * VP_VB CONJ_CC VP_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_DOZ -> NP_NN * NP_NN VERB_DOZ NP_PPS NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_HVZ -> NP_NN * pt_verb_hvz NP_NNS PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_HVZ -> NP_NN * pt_verb_hvz NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_HVZ -> NP_NN * pt_verb_hvz NP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_HVZ -> NP_NN * pt_verb_hvz NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_HVZ -> NP_NN * pt_verb_hvz NP_AP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_MD -> NP_NN * VERB_MD INFCL_BE pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_MD -> NP_NN * VERB_MD NP_NN TAG_BEZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_MD -> NP_NN * VERB_MD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_DOZ NP_NN VERB_VB PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_DOZ NP_NN VERB_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB PP_NP NP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_DOZ NP_DT VERB_VB PREP_IN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_DOZ NP_NP VERB_VB PREP_IN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_MD VERB_VB NP_PPO PP_NP PP_NP PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_MD VERB_VB NP_PPO pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * NP_DT VERB_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_MD VERB_VB PP_NP PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB PP_NPS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_MD VERB_VB NP_PPO PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_DT IJ_UH AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * pt_verb_do NP_NNS VERB_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * pt_verb_do NP_PPSS VERB_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * AVP_RBT VERB_VB NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_DOZ NP_NN VERB_VB PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB PP_NP NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_DOZ NP_NP VERB_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_NP NREL_DOZ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_MD VERB_VB PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB PP_NP PP_VBG pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_DTS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_VB NP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * pt_verb_do NP_NNS VERB_VB PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VB -> NP_NN * VERB_MD NP_PPSS VERB_VB NP_PPO PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBD -> NP_NN * VERB_VBD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBG -> NP_NN * VERB_MD NP_PPSS pt_verb_be VERB_VBG PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBG -> NP_NN * VERB_MD pt_verb_be VERB_VBG NP_NNS NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ VERB_VBN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ VERB_VBN PP_NN AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ VERB_VBN PP_NP AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * pt_verb_ber VERB_VBN PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ VERB_VBN PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ VERB_VBN PP_CD AVPNP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ VERB_VBN PP_NN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * pt_verb_ber VERB_VBN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ pt_verb_beg VERB_VBN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBN -> NP_NN * VERB_BEZ VERB_VBN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ AVP_RB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_CD NP_VBG pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NP PP_NP AVPNP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_NP AVP_RBT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NP PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * AVP_RB VERB_VBZ NP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NP PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ NP_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NP PP_NP PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_CC PP_NN NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] DECL_VBZ -> NP_NN * VERB_VBZ PP_CC PP_NNS NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_CC -> NP_NN * CONJ_CC NP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_CC -> NP_NN * CONJ_CC NP_PPSS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_CC -> NP_NN * CONJ_CC NP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_CC -> NP_NN * CONJ_CC NP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_CC -> NP_NN * CONJ_CC NP_VBG
# |[---->    .    .    .    .    .    .    .| [0:1] NP_CC -> NP_NN * CONJ_CC NP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_CC -> NP_NN * CONJ_CC NP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN NAPPOS_NP PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN AJP_JJ pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PRPRTCL_VBG
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN NOUN_NPS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_NP PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NP NOUN_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PTPRTCL_VBN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * AJP_JJ NOUN_NN NAPPOS_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN LABEL_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_NPS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NP_NN NOUN_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_CD pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_NP PP_NN PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN LABEL_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN RELCL_VB
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN NAPPOS_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NP AJP_JJT NOUN_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_DTS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NN PP_NN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN PP_VBG
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN AJP_JJT pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NP PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_CD
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN INFCL_VBN
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN PP_NP PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NPS PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN NAPPOS_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NPS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN AVP_RB
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NP NOUN_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NP_NN NOUN_NN PP_CC pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * AJP_JJT NOUN_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NN PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NN -> NP_NN * NOUN_NN PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS AVP_RB PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS INFCL_VB pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PTPRTCL_VBN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NP PP_NP
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS NAPPOS_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NP_NNS NOUN_NNS PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NP PP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PRPRTCL_VBG pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NP_NN NOUN_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * AJP_JJ NOUN_NNS PP_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NP_NN NP_NN NOUN_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NP_NN NOUN_NNS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NP PP_NPS
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NNS pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NP PP_CC
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS NAPPOS_NP PP_NP pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * NOUN_NNS PP_NP PP_NP PP_NN pt_char_per
# |[---->    .    .    .    .    .    .    .| [0:1] NP_NNS -> NP_NN * AJP_JJ NOUN_NNS RELCL_VB pt_char_per
# ...
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * VERB_HV NP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * pt_verb_do NP_PPSS VERB_HV PP_NP PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * pt_verb_do NP_PPSS VERB_HV INFCL_VB pt_char_per
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * VERB_DOZ NP_NP VERB_HV PP_NN AVP_RB pt_char_per
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * pt_verb_do NP_PPSS VERB_HV PP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * VERB_DOZ NP_NP VERB_HV pt_char_per
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * VERB_HV AVP_RB pt_char_per
# |.               [--------------->| [1:2] DECL_HV -> NP_NNS * VERB_DOZ NP_NP VERB_HV PRPRTCL_VBG pt_char_per
# |.               [--------------->| [1:2] DECL_HVZ -> NP_NNS * pt_verb_hvz NP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_MD -> NP_NNS * pt_verb_ber VERB_MD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP PP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_CC pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_CC pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_CC pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * IJ_UH VERB_VB pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * AVP_RB VERB_VB PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NN PP_CD AVPNP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP PP_NNS PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_NP PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP PP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_CC PP_DT pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_NP PP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NPS PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_DOZ NP_NN VERB_VB PREP_IN PREP_IN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NNS PP_CC pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_CC pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_DOZ NP_NN VERB_VB pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP PP_DTS IJ_UH AVPNP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_CD AVPNP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NN AVP_RB pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB AVPNP_NP PP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_DTS PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_DOZ NP_NN VERB_VB PREP_IN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB AVPNP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_DTS pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * pt_verb_do NP_PPSS VERB_VB pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB AVPNP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP PP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NN AVPNP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB AVP_RB NP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_MD VERB_VB PREP_IN PP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP AVP_RB pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP AVPNP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_CD pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_DOZ NP_NP VERB_VB pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PREP_IN PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_NN PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_PN pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_CC PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP PP_CC pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP PP_NP AVPNP_NNS PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB PP_NP AVPNP_DTS pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> NP_NNS * VERB_VB NP_NP PP_NN PP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_VBN -> NP_NNS * pt_verb_ber VERB_VBN PP_NN pt_char_per
# |.               [--------------->| [1:2] DECL_VBN -> NP_NNS * pt_verb_ber VERB_VBN PP_NPS AJP_JJ pt_char_per
# |.               [--------------->| [1:2] DECL_VBN -> NP_NNS * pt_verb_ber VERB_VBN PP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_VBZ -> NP_NNS * VERB_VBZ NP_AP pt_char_per
# |.               [--------------->| [1:2] DECL_VBZ -> NP_NNS * VERB_VBZ AVP_RB pt_char_per
# |.               [--------------->| [1:2] DECL_VBZ -> NP_NNS * VERB_VBZ NP_NNS pt_char_per
# |.               [--------------->| [1:2] DECL_VBZ -> NP_NNS * VERB_VBZ AVP_RBT pt_char_per
# |.               [--------------->| [1:2] DECL_VBZ -> NP_NNS * VERB_VBZ PP_NP PP_NP PP_NN pt_char_per
# |.               [--------------->| [1:2] NP_CC -> NP_NNS * CONJ_CC NP_NNS
# |.               [--------------->| [1:2] NP_CC -> NP_NNS * CONJ_CC NP_NNS pt_char_per
# |.               [--------------->| [1:2] NP_CC -> NP_NNS * CONJ_CC NP_NN
# |.               [--------------->| [1:2] NP_CC -> NP_NNS * CONJ_CC NP_NP
# |.               [--------------->| [1:2] NP_CC -> NP_NNS * CONJ_CC NP_CD
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NOUN_NN PP_NNS
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NOUN_NN pt_char_per
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NOUN_NN PP_NNS pt_char_per
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NP_NN QUANP_CD NOUN_NN PP_NP
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * QUANP_CD NOUN_NN
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NP_NP NOUN_NN pt_char_per
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NOUN_NN LABEL_CD
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NOUN_NN
# |.               [--------------->| [1:2] NP_NN -> NP_NNS * NOUN_NN PP_NP PP_NN
# |.               [--------------->| [1:2] NP_NNS -> NP_NNS * NOUN_NNS PRPRTCL_VBG pt_char_per
# |.               [--------------->| [1:2] NP_NNS -> NP_NNS * NOUN_NNS PP_CD pt_char_per
# |.               [--------------->| [1:2] NP_NNS -> NP_NNS * NOUN_NNS
# |.               [--------------->| [1:2] NP_NNS -> NP_NNS * NOUN_NNS PRPRTCL_VBG
# |.               [--------------->| [1:2] NP_NNS -> NP_NNS * NOUN_NNS PP_NP PP_NP
# |.               [--------------->| [1:2] NP_NNS -> NP_NNS * NP_NN QUANP_CD AJP_JJ NP_NP NP_NN NOUN_NNS pt_char_per
# |.               [--------------->| [1:2] NP_NNS -> NP_NNS * NOUN_NNS PP_NNS
# |.               [--------------->| [1:2] NREL_BER -> NP_NNS * pt_verb_ber AVP_RB NP_NN pt_char_per
# |.               [--------------->| [1:2] NREL_BER -> NP_NNS * pt_verb_ber NP_NNS
# |.               [--------------->| [1:2] NREL_BER -> NP_NNS * pt_verb_ber AJP_JJ
# |.               [--------------->| [1:2] NREL_BER -> NP_NNS * pt_verb_ber AJP_JJ PP_NN PP_CD
# |.               [--------------->| [1:2] NREL_BER -> NP_NNS * pt_verb_ber AVP_RB pt_char_per
# |.               [--------------->| [1:2] NREL_BER -> NP_NNS * pt_verb_ber AVP_RB NP_NP
# |.               [--------------->| [1:2] NREL_CC -> NP_NNS * VP_VBN CONJ_CC VP_VB
# |.               [--------------->| [1:2] NREL_CC -> NP_NNS * VP_VB CONJ_CC VP_VB pt_char_per
# |.               [--------------->| [1:2] NREL_CC -> NP_NNS * VP_VB CONJ_CC VP_VB
# |.               [--------------->| [1:2] NREL_DO -> NP_NNS * pt_verb_do
# |.               [--------------->| [1:2] NREL_HV -> NP_NNS * VERB_HV NP_VBG pt_char_per
# |.               [--------------->| [1:2] NREL_HV -> NP_NNS * VERB_HV pt_char_per
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_VB
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_VB PP_NP PP_NP pt_char_per
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_MD VERB_HV VERB_VB NP_NN
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_VB PP_NP pt_char_per
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_HV VERB_VB NP_NN
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_VB PP_NP PP_NP
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_VB PP_CC pt_char_per
# |.               [--------------->| [1:2] NREL_VB -> NP_NNS * VERB_VB PP_CD pt_char_per
# |.               [--------------->| [1:2] NREL_VBG -> NP_NNS * pt_verb_ber VERB_VBG PP_NP PP_CC pt_char_per
# |.               [--------------->| [1:2] NREL_VBN -> NP_NNS * VERB_BEZ VERB_VBN PP_NN AVPNP_CD
# |.               [--------------->| [1:2] RELCL_BEZ -> NP_NNS * VERB_BEZ
# |.               [--------------->| [1:2] RELCL_CC -> NP_NNS * AVP_RB VP_VB CONJ_CC VP_VB
# |.               [--------------->| [1:2] RELCL_HV -> NP_NNS * VERB_HV NP_NN
# |.               [--------------->| [1:2] RELCL_VB -> NP_NNS * VERB_VB PREP_IN
# |.               [--------------->| [1:2] RELCL_VB -> NP_NNS * VERB_VB NP_NP PP_CD
# |.               [--------------->| [1:2] RELCL_VBG -> NP_NNS * VERB_MD pt_verb_be VERB_VBG PP_NP
# |.               [--------------->| [1:2] RELCL_VBN -> NP_NNS * VERB_BEZ VERB_VBN PREP_IN
# |.               [---------------]| [1:2] SIGMA -> NP_NNS *
# |.               [--------------->| [1:2] VP_VB -> NP_NNS * VERB_MD VERB_VB SUBCL_VB
# |.               [--------------->| [1:2] VP_VB -> NP_NNS * VERB_VB NP_CD
# Single Edge Fundamental Rule:
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NNS PP_NP pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * NP_NNS pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NP PP_NPS PP_NP pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NNS pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * AVPNP_NN pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * AVPNP_NP pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_CC pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * AVPNP_CD pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_CD AVPNP_CD pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NP PP_NP PP_NP pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_CD PP_NN pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * NP_NN PP_NN pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NP PP_NN pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * NP_NN pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NP PP_NP pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NN pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NP pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * NP_NN PP_CD pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_NP PP_CD pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * PP_CD pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * AJP_JJ pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * IJ_UH pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * RELCL_BEZ pt_char_per
# |[------------------------------->| [0:2] IMPR_VB -> VERB_VB NP_NNS * AVP_RB pt_char_per
# |[------------------------------->| [0:2] VP_VB -> VERB_VB NP_NNS * PP_NP PP_NP PP_NP
# |[===============================]| [0:2] VP_VB -> VERB_VB NP_NNS *
# |[------------------------------->| [0:2] NP_NNS -> NP_NN NP_NNS * NOUN_NNS PP_NP PP_NN pt_char_per
# |[------------------------------->| [0:2] NP_NNS -> NP_NN NP_NNS * NOUN_NNS PP_CC pt_char_per
# |[------------------------------->| [0:2] NP_NNS -> NP_NN NP_NNS * NOUN_NNS PP_NP PP_NP pt_char_per
# |[------------------------------->| [0:2] NP_NNS -> NP_NN NP_NNS * NOUN_NNS pt_char_per
# Bottom Up Predict Combine Rule:
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_DOZ pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_MD pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_VBN CONJ_CC VP_BEZ pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_VBG pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_BE pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_VB pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_HVZ pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_BEZ pt_char_per
# |[------------------------------->| [0:2] DECL_CC -> VP_VB * CONJ_CC VP_CC pt_char_per
# |[------------------------------->| [0:2] IMPR_CC -> VP_VB * CONJ_CC VP_VB pt_char_per
# Bottom Up Predict Combine Rule:
# |.               [--------------->| [1:2] DECL_MD -> AVPNP_NNS * pt_verb_do NP_PPSS VERB_MD INFCL_VB pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> AVPNP_NNS * VERB_MD NP_PPSS VERB_VB NP_NN PP_NP pt_char_per
# |.               [--------------->| [1:2] DECL_VB -> AVPNP_NNS * VERB_DOZ NP_NN VERB_VB NP_NN pt_char_per
# 1

# %% [markdown]
# ## 3. Probabilistic Context Free Grammars (PCFG)
#
# PCFGs are very similar to CFGs - they just have an additional probability for each production.
#
# For a given left-hand-side non-terminal, the sum of the probabilities must be 1.0!

# %%
weighted_rules = [
    'S -> NP VP [1.0]',
    'NP -> Det N [0.6]',
    'NP -> Det N PP [0.3]',
    'NP -> PRON [0.1]',
    'VP -> V NP [0.7]',
    'VP -> V NP PP [0.3]',
    'PP -> P NP [1.0]',
    'Det -> "the" [0.5]',
    'Det -> "a" [0.5]',
    'N -> "man" [0.5]',
    'N -> "telescope" [0.5]',
    'PRON -> "I" [1.0]',
    'V -> "saw" [1.0]',
    'P -> "with" [1.0]'   
]

toy_grammar = nltk.PCFG.fromstring(weighted_rules)

print(toy_grammar)
# Out:
# Grammar with 14 productions (start state = S)
#     S -> NP VP [1.0]
#     NP -> Det N [0.6]
#     NP -> Det N PP [0.3]
#     NP -> PRON [0.1]
#     VP -> V NP [0.7]
#     VP -> V NP PP [0.3]
#     PP -> P NP [1.0]
#     Det -> 'the' [0.5]
#     Det -> 'a' [0.5]
#     N -> 'man' [0.5]
#     N -> 'telescope' [0.5]
#     PRON -> 'I' [1.0]
#     V -> 'saw' [1.0]
#     P -> 'with' [1.0]

# %% [markdown]
# On top of right-hand side and left-hand side, probabilistic rules have probabilities.

# %%
rule = toy_grammar.productions()[0]
print(rule.lhs())
print(rule.rhs())
print(rule.prob())
# Out:
# S
# (NP, VP)
# 1.0

# %% [markdown]
# ### 3.1. Learning Grammars from a Treebank
#
# The most important method consists of inducing a PCFG from trees in a treebank (`induce_pcfg()`).
#
# NLTK provides portion of Penn Treebank corpus, which we can utilize to induce rules.

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to /home/dhilab-
# [nltk_data]     mattia/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %% [markdown]
# Production rules can be extracted using `productions()` method iterating over parsed sentences in the corpus.

# %%
from nltk.corpus import treebank

print(treebank)

productions = []
# let's keep it small
for item in treebank.fileids():
    for tree in treebank.parsed_sents(item):
        productions += tree.productions()
    
print(len(productions))
# Out:
# <BracketParseCorpusReader in '.../corpora/treebank/combined' (not loaded yet)>
# 179360

# %% [markdown]
# The grammar can be induced as follows:

# %%
from nltk import Nonterminal
S = Nonterminal('S')
grammar = nltk.induce_pcfg(S, productions)

# %%
grammar
# Out:
# <Grammar with 21763 productions>

# %% [markdown]
# ### 3.2. PCFG Parsers in NLTK
# NLTK provides several PCFG parsers:
#
# From `nltk.parse.viterbi`
#
# - ViterbiParser
#     - A bottom-up PCFG parser that uses dynamic programming to find the single most likely parse for a text. The ViterbiParser parser parses texts by filling in a “most likely constituent table”. This table records the most probable tree representation for any given span and node value. In particular, it has an entry for every start index, end index, and node value, recording the most likely subtree that spans from the start index to the end index, and has the given node value.
#
# From `nltk.parse.pchart` module
#
# - InsideChartParser
#     - A bottom-up parser for PCFG grammars that tries edges in descending order of the inside probabilities of their trees.
#     - use `beam_size = len(tokens)+1` argument
#
# - RandomChartParser
#     - A bottom-up parser for PCFG grammars that tries edges in random order. This sorting order results in a random search strategy.
#
# - UnsortedChartParser
#     - A bottom-up parser for PCFG grammars that tries edges in whatever order.
#
# - LongestChartParser
#     - A bottom-up parser for PCFG grammars that tries longer edges before shorter ones. This sorting order results in a type of best-first search strategy.
#
# Read about them in the [documentation](http://www.nltk.org/api/nltk.parse.html).

# %% [markdown]
# Let's parse one of the sentences from above using Viterbi parser.

# %%
parser = nltk.ViterbiParser(grammar)
for tree in parser.parse("Show me flights from New York to Los Angeles".split()):
    print(tree)
# Out:
# (S
#   (NP-SBJ (NNP Show))
#   (NP-PRD
#     (NP (NP (PRP me)) (NNS flights))
#     (PP
#       (IN from)
#       (NP
#         (NP (NNP New) (NNP York))
#         (PP (TO to) (NP (NNP Los) (NNP Angeles))))))) (p=1.23346e-35)

# %% [markdown]
# ### Exercise
#
# - Try different parser to parse the sentences from the exercises above
# - Compare assigned probabilities
# - Compare time it takes to parse sentences

# %%
tokenized_sentence = "show me flights from New York to Los Angeles".split()

# %%
# %%time
parser = nltk.ViterbiParser(grammar)
for tree in parser.parse(tokenized_sentence):
    print(tree)
# Out:
# (S
#   (NP-SBJ (NN show))
#   (NP-PRD
#     (NP (NP (PRP me)) (NNS flights))
#     (PP
#       (IN from)
#       (NP
#         (NP (NNP New) (NNP York))
#         (PP (TO to) (NP (NNP Los) (NNP Angeles))))))) (p=2.0478e-35)
# CPU times: user 4.26 s, sys: 1.02 ms, total: 4.26 s
# Wall time: 4.27 s

# %%
# %%time
parser = nltk.ChartParser(grammar)
for tree in parser.parse(tokenized_sentence):
    print(tree)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/.local/lib/python3.10/site-packages/nltk/parse/chart.py:1474, in ChartParser.parse(self, tokens, tree_class)
#    1473 def parse(self, tokens, tree_class=Tree):
# -> 1474     chart = self.chart_parse(tokens)
#    1475     return iter(chart.parses(self._grammar.start(), tree_class=tree_class))
#
# File ~/.local/lib/python3.10/site-packages/nltk/parse/chart.py:1455, in ChartParser.chart_parse(self, tokens, trace)
#    1453 edge = agenda.pop()
#    1454 for rule in inference_rules:
# -> 1455     new_edges = list(rule.apply(chart, grammar, edge))
#    1456     if trace:
#    1457         trace_new_edges(chart, rule, new_edges, trace, trace_edge_width)
#
# File ~/.local/lib/python3.10/site-packages/nltk/parse/chart.py:1070, in SingleEdgeFundamentalRule.apply(self, chart, grammar, edge)
#    1068     yield from self._apply_incomplete(chart, grammar, edge)
#    1069 else:
# -> 1070     yield from self._apply_complete(chart, grammar, edge)
#
# File ~/.local/lib/python3.10/site-packages/nltk/parse/chart.py:1077, in SingleEdgeFundamentalRule._apply_complete(self, chart, grammar, right_edge)
#    1073 for left_edge in chart.select(
#    1074     end=right_edge.start(), is_complete=False, nextsym=right_edge.lhs()
#    1075 ):
#    1076     new_edge = left_edge.move_dot_forward(right_edge.end())
# -> 1077     if chart.insert_with_backpointer(new_edge, left_edge, right_edge):
#    1078         yield new_edge
#
# File ~/.local/lib/python3.10/site-packages/nltk/parse/chart.py:629, in Chart.insert_with_backpointer(self, new_edge, previous_edge, child_edge)
#     627 cpls = self.child_pointer_lists(previous_edge)
#     628 new_cpls = [cpl + (child_edge,) for cpl in cpls]
# --> 629 return self.insert(new_edge, *new_cpls)
#
# File ~/.local/lib/python3.10/site-packages/nltk/parse/chart.py:660, in Chart.insert(self, edge, *child_pointer_lists)
#     657     child_pointer_list = tuple(child_pointer_list)
#     658     if child_pointer_list not in cpls:
#     659         # It's a new CPL; register it, and return true.
# --> 660         cpls[child_pointer_list] = True
#     661         chart_was_modified = True
#     662 return chart_was_modified
#
# File ~/.local/lib/python3.10/site-packages/nltk/collections.py:51, in OrderedDict.__setitem__(self, key, item)
#      49 def __setitem__(self, key, item):
#      50     dict.__setitem__(self, key, item)
# ---> 51     if key not in self._keys:
#      52         self._keys.append(key)
#
# File ~/.local/lib/python3.10/site-packages/nltk/parse/chart.py:200, in EdgeI.__eq__(self, other)
#     194     raise NotImplementedError()
#     196 # ////////////////////////////////////////////////////////////
#     197 # Comparisons & hashing
#     198 # ////////////////////////////////////////////////////////////
# --> 200 def __eq__(self, other):
#     201     return (
#     202         self.__class__ is other.__class__
#     203         and self._comparison_key == other._comparison_key
#     204     )
#     206 def __ne__(self, other):
#
# KeyboardInterrupt:

# %%
# %%time
parser = nltk.ChartParser(grammar, trace=2)
for tree in parser.parse(tokenized_sentence):
    print(tree)

# %% [markdown]
# ## 4. Generating Sentences
#
# Grammars can be used to generate sentences as well. This is accomplished using `generate` method.
# read [here](http://www.nltk.org/api/nltk.parse.html#module-nltk.parse.generate)
#
# arguments it takes are the following `nltk.parse.generate.generate(grammar, start=None, depth=None, n=None)`:
#
# - grammar – The Grammar used to generate sentences.
# - start – The Nonterminal, which is and NLTK object, from which to start generate sentences.
# - depth – The maximal depth of the generated tree.
# - n – The maximum number of sentences to return.

# %%
from nltk.parse.generate import generate

for sent in generate(toy_grammar, n=10):
    print(sent)

# %% [markdown]
# ## 5. Evaluating Constituency Parsers

# %% [markdown]
# ### 5.1. Comparing Trees

# %% [markdown]
# Since _constituency parser_ outputs _constituents_, parser evaluation is essentially a comparison between constituents of the reference and the automatic (hypothesis) parse trees (of the test set). Since constituents are labeled (have _syntactic categories_), the evaluation can also compare the reference and the hypothesis labels.
#
# A constituent in a hypothesis parse tree is considered correct, if there is a constituent in a reference parse tree that has the same span and label. That is:
#
# - has the same starting point
# - has the same ending point
# - has the same non-terminal symbol

# %% [markdown]
# Using this information we can compute precision and recall for the parser, as:
#
# $$ \text{recall} = \frac{\text{# of correct constituents in hypothesis}}{\text{# of constituents in reference}}$$
#
# $$ \text{precision} = \frac{\text{# of correct constituents in hypothesis}}{\text{# of constituents in hypothesis}}$$
#
# The $F_1$ metric is computed the usual way, as:
#
# $$F_1 = \frac{2PR}{P+R}$$

# %% [markdown]
# In case for the correct constituent counts we consider labels, we compute _labeled_ precision and recall. Otherwise, metrics are _unlabeled_.

# %% [markdown]
# ### 5.2. PARSEVAL
# The evaluation method that implements this is known as **PARSEVAL** [(Black et al., 1991)](https://aclanthology.org/H91-1060/).
#
# The metric includes an algorithm from _caninicalization_ that removes grammar-specific information and allows comparing parsers with different grammars.
#
# The "canonical" implementation of **PARSEVAL** is known as [**EVALB**](https://nlp.cs.nyu.edu/evalb/).

# %% [markdown]
# Since constitents are essentially sub-trees of a sentence parse tree, while having the same label and start and end points, they might differ in their internal structure.
#
# e.g.: `((A B) C)` vs. `(A (B C))`
#
# Consequently, there is an additional metric in **PARSEVAL** that is used to account for this -- **cross-brackets** (since parse trees are represented using bracketed notation) -- which is a simple count of such cases per sentence.
#
# However, since `((A B) C)` and `(A (B C))` have different constituents, this is already reflected in precision and recall.

# %% [markdown]
# ### 5.1. EVALB (PYTHON)
# There is no officially supported EVALB for python. However, there are few implementations available.
# The most easy to use it [PYEVALB](https://github.com/flyaway1217/PYEVALB).
#
# It is possible to compare two parse trees as the following:

# %%
#!pip install PYEVALB
from PYEVALB import scorer as eval_scorer
from PYEVALB import parser as eval_parser

pt0 = "(S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man)) (PP (P with) (NP (Det a) (N telescope)))))"
pt1 = "(S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))"

pt0_tree = eval_parser.create_from_bracket_string(pt0)
pt1_tree = eval_parser.create_from_bracket_string(pt1)

s = eval_scorer.Scorer()
result = s.score_trees(pt0_tree, pt1_tree)

# %%
print("P: {} R: {}".format(round(result.prec, 2), round(result.recall, 2)))

# %% [markdown]
# ## Lab Exercise
#
# Genrate 10 sentence by using a PCFG of your choice.
# - Experiment with depth and start paramenters
# - Experiment with at least 2 parsers
